# %% [markdown]
# week 1 | Groundwater
#
# # LESSON 1 : Introduction to the Groundwater course - Case Studies
#
# Dr. Xiang-Zhao Kong & Dr. Beatrice Marti

# %%
# Setting up the notebook
import sys
import os

# Import local libraries
sys.path.append('../../src')
from notebook_navigation import NotebookNavigation

# Create a NotebookNavigation object which can be printed at the end of the page
nav = NotebookNavigation(chapter_config_path='../../chapter_config.json')

# %% [markdown]
# # Introducing : The Case Studies
#
# ## Case Study 1 : Infrastructure Projects in Zurich, Switzerland
#
# In this case study, you step into the role of an Engineering geologist at a major Swiss consulting firm, specializing in complex urban construction projects in Zurich. You are responsible for ensuring safe construction while protecting groundwater resources and managing various geological challenges, which are:
#
# ### Limmat Valley High-Rise
# A 120m high-rise planned in the Limmat Valley with 4 underground parking levels. The excavation will reach 15m below groundwater level in the highly permeable Limmat Valley aquifer.
#
# Technical Challenges:
#
# - Estimate of groundwater inflow rates
# - Evaluation of groundwater drawdown impacts
#
# Learning Objectives: Darcy equation, aquifer properties, numerical modeling
#
# ### Uetliberg Slope Engineering
# Design of spring catchment and water reservoir on the unstable, mergeliger (marly) slope of Uetliberg.
#
# Technical Challenges:
#
# - Spring protection zones design
# - Drainage system planning
#
# Learning Objectives: Groundwater flow in fractured media, protection zones
#
# ### Thermal Use Conflict
# Multiple groundwater heat pump systems planned in a densely built area.
#
# Technical Challenges:
#
# - Thermal plume modeling
# - System interference assessment
# - Sustainable extraction rates
# - Temperature monitoring design
#
# Learning Objectives: Heat transport, thermal plume modeling
#
# ### Historic Industrial Contamination
# Former industrial site shows chlorinated hydrocarbon contamination threatening downstream drinking water wells.
#
# Technical Challenges:
#
# - Contaminant transport modeling
# - Risk assessment
# - Remediation strategy
# - Construction adaptation
#
# Learning Objectives: Contaminant transport, remediation concepts
#
# ## Case Study 2 : Well Field Management of the Zurich Water Supply, Switzerland
# As the manager of the groundwater well fields for Zurich's water supply, you ensure safe and sustainable drinking water production while managing various operational and environmental challenges.
#
# ### River Infiltration Optimization
# Balancing river water infiltration with groundwater extraction during varying river conditions.
#
# Technical Challenges:
#
# - Infiltration rate optimization
# - Water quality monitoring
# - Clogging management
# - Ecological flow maintenance
# - Regulatory compliance
#
# Learning Objectives: River-aquifer interaction, infiltration processes, water quality
#
# ### Industrial Spill Response
# Chemical spill detected upstream of well field requires immediate response and long-term monitoring.
#
# Technical Challenges:
#
# - Contaminant transport prediction
# - Well field adaptation
# - Alternative supply planning
# - Recovery strategy development
#
# Learning Objectives: Contaminant transport, emergency response, well field operation
#
# ### Well Field Modernization
# Planning and implementation of well field upgrade including new wells and monitoring systems.
#
# Technical Challenges:
#
# - Well location optimization
# - Pumping strategy design
# - Monitoring network enhancement
#
# Learning Objectives: Well design, monitoring systems, aquifer characterization
#
#
# ## Case Study 3 : Distributing limited water resources in the Fergana Valley, Uzbekistan
# As a leading scientist of the Interstate Commission for Water Coordination of Central Asia, you are responsible for distributing the transboundary water resources in the Fergana Valley, dealing with complex irrigation and groundwater management challenges across multiple countries.
#
# ### Irrigation-Induced Salinization
# Increasing soil and groundwater salinization threatening agricultural productivity in a major irrigation district.
#
# Technical Challenges:
#
# - Salinity transport modeling
# - Irrigation system optimization
# - Drainage system design
# - Sustainable farming practices
#
# Learning Objectives: Salinity transport, irrigation impacts, soil-water interaction
#
# ### Aquifer Sustainability
# Rapid groundwater level decline in transboundary aquifer requiring international cooperation.
#
# Technical Challenges:
#
# - Aquifer assessment
# - Extraction management
# - Alternative water sources
# - Policy development
#
# Learning Objectives: Aquifer management, water policy, sustainable yield
#
# ### Climate Change Adaptation
# Developing adaptation strategies for changing precipitation patterns and increasing water demand.
#
# Technical Challenges:
#
# - Climate impact assessment
# - Adaptation planning
# - Water conservation
# - Drought management
# - Stakeholder engagement
#
# Learning Objectives: Climate impacts, water conservation, adaptation strategies
#
# ### Irrigation Modernization
# Large-scale irrigation modernization project affecting groundwater recharge patterns.
#
# Technical Challenges:
#
# - Irrigation efficiency
# - Groundwater recharge
# - Water rights allocation
# - Technology adoption
#
# Learning Objectives: Irrigation-groundwater interaction, water efficiency, project management
#
# ## Case Study 4 : Environmental Scientist - Climate Change Research
# You are a climate scientist at a leading research institute, investigating the critical role of groundwater in climate change adaptation and mitigation.
#
# ### Groundwater-Dependent Ecosystem Vulnerability
# Studying the vulnerability of groundwater-dependent ecosystems to climate change in alpine regions.
#
# Technical Challenges:
#
# - Ecosystem service assessment
# - Climate scenario modeling
# - Groundwater-surface water interactions
# - Adaptation strategy development
#
# Learning Objectives: Ecosystem-groundwater interaction, climate impact assessment, adaptation planning
#
# ### Urban Heat Island and Groundwater
# Investigating how urban groundwater systems can help mitigate the urban heat island effect.
#
# Technical Challenges:
#
# - Urban aquifer characterization
# - Heat transport modeling
# - Green infrastructure planning
# - Policy recommendation development
# - Stakeholder engagement
#
# Learning Objectives: Urban hydrogeology, heat transport, climate adaptation
#
# ### Sea Level Rise Impacts
# Assessing threats of sea-level rise and changing precipitation patterns on coastal aquifers.
#
# Technical Challenges:
#
# - Saltwater intrusion modeling
# - Climate scenario analysis
# - Adaptation strategy development
#
# Learning Objectives: Coastal hydrogeology, saltwater intrusion, climate adaptation
#
# ### Agricultural Water Security
# Researching climate effects on groundwater availability for agriculture.
#
# Technical Challenges:
#
# - Agricultural water demand modeling
# - Climate impact assessment
# - Irrigation efficiency analysis
# - Crop water stress prediction
# - Farmer adaptation planning
#
# Learning Objectives: Agricultural water use, climate impacts, sustainable management
#
# ### Groundwater and Carbon Sequestration
# Investigating the role of groundwater systems in carbon sequestration.
#
# Technical Challenges:
#
# - Carbon flux assessment
# - Aquifer storage capacity
# - Monitoring strategy design
#
# Learning Objectives: Carbon cycling, environmental impact assessment, policy development

# %%
nav.display_navigation('case_studies')
# Out:
# <div style="display: flex; justify-content: space-between; padding: 20px;">
# <a href="introduction.ipynb" style="text-decoration: none; color: #2196F3;">← Previous: Introduction to the course</a>
# <a href="../../02_groundwater_flow/notebook/groundwater_flow.ipynb" style="text-decoration: none; color: #2196F3;">Next: Groundwater Flow →</a>
# </div>
