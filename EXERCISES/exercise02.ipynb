# %%
# Setting up the notebook
import sys
import os
import matplotlib.pyplot as plt

# Import local libraries
sys.path.append('../SUPPORT_REPO/src/scripts/scripts_exercises')
from shared_functions import check_task_with_solution
from darcy_law_experiment import darcy_experiment_simulation_global
import print_images as du

# %% [markdown]
# # Exercise 2 : Darcy law derivation and use

# %% [markdown]
# ## Context
#
# You are given a Darcy experiement set-up :

# %%
du.display_image(
    image_filename='DarcyExperimentSetup.png', 
    image_folder='3_exercises', 
    )

# %% [markdown]
# ## Empirical derivation
#
# We want to derive experimentally Darcy's law, which relates 2 measurable quantities:
# - **Hydraulic gradient** $I$ = $\frac{\Delta h}{L}$, with $\Delta h$ the hydraulic gradient (ie. hydraulic head differenve between the input and the output of the column)
# - **Specific discharge** $q$ at the input (or output, since a steady state flow is assumed).
#
# You might later need some additionnal parameters:
# - Column radius $r = d/2 = 0.127$ mm
# - Column length $L = 1$ m
#
# The experiment below repeats $q$ measurements for different $\Delta h$ values, to plot $q$ against $I$.

# %%
darcy_experiment_simulation_global()

# %% [markdown]
# ## Darcy's law use

# %% [markdown]
# In our simulation, the soil column had an hydraulic conductivity $K$=0.0003 $\text{m}\text{s}^{-1}$. However, each soil column has a different hydraulic conductivity.
#
# **Tsalet catchment** mixed deposits :
# - hydraulic conductivity **$K_{T}$=0.0005 $\text{m}\text{s}^{-1}$**,
# - effective porosity **$\phi_e$=0.2**. <br><br>
#
# Let's assume we refill our Darcy experiment setup's column with Tsalet catchment mixed deposits.

# %% [markdown]
# ### Task 2.1

# %%
check_task_with_solution("task03_1")
# Out:
# With Tsalet's mixed deposits in the setup column, you now observe that $\Delta h=0.4$ m.
# - **What is your estimate of the specific discharge $q$ in mm/s?**
# ...
# Output()
# Button(description='Show Solution', disabled=True, style=ButtonStyle())
# Output()

# %% [markdown]
# ### Task 2.2

# %%
check_task_with_solution("task03_2")
# Out:
# - **What is the discharge $Q$ in the soil column in mm/s?**
# ...
# Output()
# Button(description='Show Solution', disabled=True, style=ButtonStyle())
# Output()

# %% [markdown]
# ### Task 2.3

# %%
check_task_with_solution("task03_3")
# Out:
# - **What is the mean velocity of water $u$ in the soil column in mm/s?**
# ...
# Output()
# Button(description='Show Solution', disabled=True, style=ButtonStyle())
# Output()

# %% [markdown]
# > ✅ **Equation reminder: Darcy's law**
# >
# > In an homogeneous and isotropic porous medium, hydraulic conductivity is the specific discharge per unit hydraulic gradient : q = KI.
# >
# > This law is is named after Darcy, who was the scientist developping the experiment showing that reationship.
