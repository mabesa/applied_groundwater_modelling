# %%
# Setting up the notebook
import sys
import os
import matplotlib.pyplot as plt

# Import local libraries
sys.path.append('../SUPPORT_REPO/src/scripts/scripts_exercises')
from shared_functions import check_task_with_solution
import print_images as du

# %% [markdown]
# # Exercise 1 : Groundwater balance

# %% [markdown]
# ## Context
#
# This exercise focuses on an alpine headwater catchment, the Tsalet catchment, located in Wallis (see BAFU map below).
# - Net recharge rate (yearly average), $P$ :  1 mm/day [\[1\]](#references)
# - Source output, mean discharge rate, $Q$ : 20 L/s (continuous streamflow in the Tsalet stream) [\[1\]](#references)
# - Acquifer porosity, $\phi$ : 0.2

# %% [markdown]
# ## Map of the situation

# %%
du.display_image(
    image_filename='SwissTopoTsaletCatchment.png', 
    image_folder='3_exercises', 
    )

# %% [markdown]
# ## Tasks

# %%
# Launch the tasks
check_task_with_solution("task01_1")
check_task_with_solution("task01_3")
# Out:
# ## Task 1:
# We can assume the system to be at a steady state.
#  - **Estimate $A$ the area of the Tsalet catchment in $\text{km}^2$**
# HBox(children=(FloatText(value=0.0, description='Answer:', style=DescriptionStyle(description_width='initial')…
# Output()
# Button(description='Show Solution', disabled=True, style=ButtonStyle())
# Output()
# ## Task 2:
# Based on the previous results :
# - **Estimate $M_{aq}$ the mean thickness of the aquifer**"
# HBox(children=(FloatText(value=0.0, description='Answer:', style=DescriptionStyle(description_width='initial')…
# Output()
# Button(description='Show Solution', disabled=True, style=ButtonStyle())
# Output()

# %% [markdown]
# ## Uncertainty on the Area result

# %% [markdown]
# We are interested in investigating the uncertainties in $A$ estimation. Indeed, the BAFU area is pretty close to our result [\[2\]](#references), but we can still notice a difference.
#
# To compute the catchment area, we used both the net recharge rate $P$ and the output river discharge rate $Q$. You are now given uncertainties on initial data values:
#
# - Net recharge rate (yearly average), $P$ =  $1.0\pm0.1$ mm/day [\[1\]](#references)
# - Source output, mean discharge rate, $Q$ = $20\pm5$ L/s (continuous streamflow in the Tsalet stream) [\[1\]](#references)

# %%
# Launch the tasks
check_task_with_solution("task01_4")
# Out:
# ## Task 3:
# Given the uncertainty intervals for $P$ and $Q$ :
# - **Estimate the lower bound of *A* uncertainty interval**
# HBox(children=(FloatText(value=0.0, description='Answer:', style=DescriptionStyle(description_width='initial')…
# Output()
# Button(description='Show Solution', disabled=True, style=ButtonStyle())
# Output()

# %% [markdown]
# ## References
#
# \[1\] Halloran, Landon & Millwater, Jeremy & Hunkeler, Daniel & Arnoux, Marie. (2023). "Climate change impacts on groundwater discharge-dependent streamflow in an alpine headwater catchment". Science of The Total Environment. 902. 166009. 10.1016/j.scitotenv.2023.166009.
#
# \[2\] https://map.geo.admin.ch/#/map?lang=en&center=2605504.32,1115286.67&z=6.517&topic=ech&layers=ch.swisstopo.swisseo_vhi_v100,f;ch.swisstopo.swisseo_vhi_v100_vegetation,f;ch.bafu.wasser-teileinzugsgebiete_2@features=151831&bgLayer=ch.swisstopo.pixelkarte-farbe&featureInfo=default
