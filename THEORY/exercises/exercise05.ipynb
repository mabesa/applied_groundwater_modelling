# %%
# Setting up the notebook
import sys
import os

# Import local libraries
sys.path.append('../../_SUPPORT/src/scripts/scripts_exercises')
from formulation_problems import boundary_condition_matching, sources_and_sinks_matching, flow_equation_matching,  flow_analytical_solutions_matching

# %% [markdown]
# # Exercise 5 : Flow Problems

# %% [markdown]
# ## Context :
#
# When solving groundwater problems, an important part of the work consists in defining and solving the flow problem part.
#
# This includes for any studied groundwater system:
# - identifying flow boundary conditions
# - identifying all water sources and sink terms
# - formulating the flow analytical equations to be solved
# - solving the flow equations, analytically or numerically

# %% [markdown]
# ## Task 1 : Boundary Conditions
#
#
# - **Match the correct expression to each possible boundary condition**:

# %%
boundary_condition_matching()

# %% [markdown]
# ## Task 2 : Source and Sink Terms
#
# - **Match the correct expression to each possible source or sink term:**

# %%
sources_and_sinks_matching()

# %% [markdown]
# ## Task 3 : Analytical formulation of simple problems
#
# - **Match the correct expression to each presented simple flow equation:**

# %%
flow_equation_matching()

# %% [markdown]
# ## Task 4 : Analytical solution to simple problems
#
# - **Match the correct expression to each presented analytical solution equation:**

# %%
flow_analytical_solutions_matching()
