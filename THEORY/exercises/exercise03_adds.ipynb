# %%
# Setting up the notebook
import sys
import os

# Import local libraries
sys.path.append('../../_SUPPORT/src/scripts/scripts_exercises')
from formulation_problems import transport_matching, transport_observation_matching, transport_gaussian_plot, transport_boundary_condition_matching
from solution_transport import question_tracer_propagation_plot, plot_curve_and_question_estimation

# %% [markdown]
# # Exercise 3 : Flow in a confined sandstone aquifer

# %% [markdown]
# In a confined sandstone aquifer of thickness $m$ = 10 m,
# two observation wells are installed.
# The aquifer is sloped with an angle of an angle $\alpha$.
# The water flows sucessively through two consecutive sections of the aquifer of lengths L1 = L2 = 100 m.
# The measured piezometric head in the piezometers are
# $h_1$=510 m, and $h_2$ = 500 m. From a pumping test analysis the hydraulic conductivity was
# $K_1$=5.0 10^{-5} m s-1, and $K_2$=1.0 10${-4} m s-1.
# It is assumed that the values belong to two consecutive sections of the aquifer of lengths L1 = L2 = 100 m.
# A summary figure is presented in the next part.

# %% [markdown]
# Figure: Cross section of confined aquifer
# a) Calculate and draw the piezometric head surface between the two piezometers.
# b) Determine the discharge per unit width of the aquifer.

# %% [markdown]
# Exercise flownet

# %% [markdown]
# The figure below shows a flow net of an aquifer beneath an impervious dam.
# Blue solid lines represent streamlines.
# Red dashed lines are equipotential lines, indicating hydraulic head (h) in meters, with equal differences between values.
# - The geological datum is set to 0 m at the bottom of the two surface reservoirs.
# - The hydraulic head is h = 23 m at the water surface of the upstream reservoir, which is 20 m higher than the hydraulic head at the downstream reservoir.
# - The aquifer has a constant, isotropic hydraulic conductivity of 5×10-5 m/s.

# %%
sys.path.append('../../_SUPPORT/src/scripts/scripts_exercises')
from shared_functions import check_task_with_solution
import print_images as du

du.display_image(image_filename='FlowNet_exercise.png', image_folder='3_exercises')
check_task_with_solution("task_exercise_flow_net_1")
check_task_with_solution("task_exercise_flow_net_2")
check_task_with_solution("task_exercise_flow_net_3")
# Out:
# ## Task 1
# Compute the hydraulic head at point A (in meter)
# ...
# Output()
# Button(description='Show Solution', disabled=True, style=ButtonStyle())
# Output()
# ## Task 2
# Compute the pressure gradient (in kPa/m) of pore water between Points B and C which are at the same elevation.
# ...
# Output()
# Button(description='Show Solution', disabled=True, style=ButtonStyle())
# Output()
# ## Task 3
# Compute the groundwater discharge of unit aquifer width (in $cm^3$/s) in the Box D which has a dimension of 10 m by 10 m.
# ...
# Output()
# Button(description='Show Solution', disabled=True, style=ButtonStyle())
# Output()
